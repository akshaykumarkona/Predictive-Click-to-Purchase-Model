# %% [markdown]
# # Predicting whether a User purchases the product which he has clicked on an ad

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Collection

# %%
ds=pd.read_csv("user_data.csv")
ds.head(10)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0
# 5  15728773    Male   27            58000          0
# 6  15598044  Female   27            84000          0
# 7  15694829  Female   32           150000          1
# 8  15600575    Male   25            33000          0
# 9  15727311  Female   35            65000          0

# %%
ds.shape
# Out:
# (400, 5)

# %% [markdown]
# ## Data Analysis

# %%
ds.isna()
# Out:
#      User ID  Gender    Age  EstimatedSalary  Purchased
# 0      False   False  False            False      False
# 1      False   False  False            False      False
# 2      False   False  False            False      False
# 3      False   False  False            False      False
# 4      False   False  False            False      False
# ..       ...     ...    ...              ...        ...
# 395    False   False  False            False      False
# 396    False   False  False            False      False
# 397    False   False  False            False      False
# 398    False   False  False            False      False
# 399    False   False  False            False      False
#
# [400 rows x 5 columns]

# %%
ds.isna().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
ds['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
ds['Age'].unique()
# Out:
# array([19, 35, 26, 27, 32, 25, 20, 18, 29, 47, 45, 46, 48, 49, 31, 21, 28,
#        33, 30, 23, 24, 22, 59, 34, 39, 38, 37, 42, 40, 36, 41, 58, 55, 52,
#        60, 56, 53, 50, 51, 57, 44, 43, 54], dtype=int64)

# %%
ds['Age'].nunique()
# Out:
# 43

# %%
ds['EstimatedSalary'].unique()
# Out:
# array([ 19000,  20000,  43000,  57000,  76000,  58000,  84000, 150000,
#         33000,  65000,  80000,  52000,  86000,  18000,  82000,  25000,
#         26000,  28000,  29000,  22000,  49000,  41000,  23000,  30000,
#         74000, 137000,  16000,  44000,  90000,  27000,  72000,  31000,
#         17000,  51000, 108000,  15000,  79000,  54000, 135000,  89000,
#         32000,  83000,  55000,  48000, 117000,  87000,  66000, 120000,
#         63000,  68000, 113000, 112000,  42000,  88000,  62000, 118000,
#         85000,  81000,  50000, 116000, 123000,  73000,  37000,  59000,
#        149000,  21000,  35000,  71000,  61000,  75000,  53000, 107000,
#         96000,  45000,  47000, 100000,  38000,  69000, 148000, 115000,
#         34000,  60000,  70000,  36000,  39000, 134000, 101000, 130000,
#        114000, 142000,  78000, 143000,  91000, 144000, 102000, 126000,
#        133000, 147000, 104000, 146000, 122000,  97000,  95000, 131000,
# ...

# %%
ds['EstimatedSalary'].nunique()
# Out:
# 117

# %%
ds['Purchased'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
ds.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
plt.bar(ds['Purchased'],ds['Age'],width=0.2)
plt.xlabel("Purchased")
plt.ylabel("Age")
plt.title("Purchased vs Age")
plt.show()

# %%
plt.bar(ds['Purchased'],ds['Gender'],width=0.2)
plt.xlabel("Purchased")
plt.ylabel("Gender")
plt.title("Purchased vs Gender")
plt.show()

# %%
plt.scatter(ds['Purchased'],ds['EstimatedSalary'])
plt.xlabel("Purchased")
plt.ylabel("EstimatedSalary")
plt.title("Purchased vs EstimatedSalary")
plt.show()

# %%
plt.scatter(ds['Gender'],ds['EstimatedSalary'])
plt.xlabel("Gender")
plt.ylabel("EstimatedSalary")
plt.title("Gender vs EstimatedSalary")
plt.show()

# %%
plt.bar(ds['Age'],ds['EstimatedSalary'])
plt.xlabel("Age")
plt.ylabel("EstimatedSalary")
plt.title("Age vs EstimatedSalary")
plt.show()

# %% [markdown]
# ## Data Pre-processing

# %%
from sklearn.preprocessing import StandardScaler as ss

# %%
s=ss()
ag=s.fit_transform(ds[['Age']])
ag
# Out:
# array([[-1.78179743],
#        [-0.25358736],
#        [-1.11320552],
#        [-1.01769239],
#        [-1.78179743],
#        [-1.01769239],
#        [-1.01769239],
#        [-0.54012675],
#        [-1.20871865],
#        [-0.25358736],
#        [-1.11320552],
#        [-1.11320552],
#        [-1.6862843 ],
#        [-0.54012675],
#        [-1.87731056],
#        [-0.82666613],
#        [ 0.89257019],
#        [ 0.70154394],
#        [ 0.79705706],
#        [ 0.98808332],
#        [ 0.70154394],
#        [ 0.89257019],
#        [ 0.98808332],
#        [ 0.70154394],
#        [ 0.79705706],
#        [ 0.89257019],
#        [ 1.08359645],
#        [ 0.89257019],
#        [-0.82666613],
#        [-0.63563988],
#        [-0.63563988],
#        [-1.01769239],
#        [-1.59077117],
#        [-0.92217926],
#        [-1.01769239],
#        [-0.25358736],
#        [-0.44461362],
#        [-0.73115301],
#        [-1.11320552],
#        [-1.01769239],
#        [-1.01769239],
# ...

# %%
ds['SAge']=ag
ds
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased      SAge
# 0    15624510    Male   19            19000          0 -1.781797
# 1    15810944    Male   35            20000          0 -0.253587
# 2    15668575  Female   26            43000          0 -1.113206
# 3    15603246  Female   27            57000          0 -1.017692
# 4    15804002    Male   19            76000          0 -1.781797
# ..        ...     ...  ...              ...        ...       ...
# 395  15691863  Female   46            41000          1  0.797057
# 396  15706071    Male   51            23000          1  1.274623
# 397  15654296  Female   50            20000          1  1.179110
# 398  15755018    Male   36            33000          0 -0.158074
# 399  15594041  Female   49            36000          1  1.083596
#
# [400 rows x 6 columns]

# %%
es=s.fit_transform(ds[['EstimatedSalary']])
es
# Out:
# array([[-1.49004624],
#        [-1.46068138],
#        [-0.78528968],
#        [-0.37418169],
#        [ 0.18375059],
#        [-0.34481683],
#        [ 0.41866944],
#        [ 2.35674998],
#        [-1.07893824],
#        [-0.13926283],
#        [ 0.30121002],
#        [-0.52100597],
#        [ 0.47739916],
#        [-1.51941109],
#        [ 0.35993973],
#        [ 0.30121002],
#        [-1.3138571 ],
#        [-1.28449224],
#        [-1.22576253],
#        [-1.19639767],
#        [-1.40195167],
#        [-0.60910054],
#        [-0.84401939],
#        [-1.40195167],
#        [-1.37258681],
#        [-1.46068138],
#        [-1.22576253],
#        [-1.16703281],
#        [-0.78528968],
#        [-1.51941109],
#        [ 0.12502088],
#        [ 1.97500684],
#        [-1.5781408 ],
#        [-0.75592482],
#        [ 0.59485858],
#        [-1.25512738],
#        [-1.22576253],
#        [-0.60910054],
#        [ 0.06629116],
#        [-1.13766796],
#        [-1.54877595],
# ...

# %%
ds['Ssalary']=es
ds
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased      SAge   Ssalary
# 0    15624510    Male   19            19000          0 -1.781797 -1.490046
# 1    15810944    Male   35            20000          0 -0.253587 -1.460681
# 2    15668575  Female   26            43000          0 -1.113206 -0.785290
# 3    15603246  Female   27            57000          0 -1.017692 -0.374182
# 4    15804002    Male   19            76000          0 -1.781797  0.183751
# ..        ...     ...  ...              ...        ...       ...       ...
# 395  15691863  Female   46            41000          1  0.797057 -0.844019
# 396  15706071    Male   51            23000          1  1.274623 -1.372587
# 397  15654296  Female   50            20000          1  1.179110 -1.460681
# 398  15755018    Male   36            33000          0 -0.158074 -1.078938
# 399  15594041  Female   49            36000          1  1.083596 -0.990844
#
# [400 rows x 7 columns]

# %%
ds.drop(['Age','EstimatedSalary'],axis=1,inplace=True)
ds
# Out:
#       User ID  Gender  Purchased      SAge   Ssalary
# 0    15624510    Male          0 -1.781797 -1.490046
# 1    15810944    Male          0 -0.253587 -1.460681
# 2    15668575  Female          0 -1.113206 -0.785290
# 3    15603246  Female          0 -1.017692 -0.374182
# 4    15804002    Male          0 -1.781797  0.183751
# ..        ...     ...        ...       ...       ...
# 395  15691863  Female          1  0.797057 -0.844019
# 396  15706071    Male          1  1.274623 -1.372587
# 397  15654296  Female          1  1.179110 -1.460681
# 398  15755018    Male          0 -0.158074 -1.078938
# 399  15594041  Female          1  1.083596 -0.990844
#
# [400 rows x 5 columns]

# %%
import seaborn as sns
sns.heatmap(ds.corr(),annot=True)
plt.figure(figsize=(50,30))
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_12248\3177357391.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(ds.corr(),annot=True)

# %%
X=ds[['SAge','Ssalary']]
Y=ds['Purchased']
print(X,Y)
# Out:
#          SAge   Ssalary
# 0   -1.781797 -1.490046
# 1   -0.253587 -1.460681
# 2   -1.113206 -0.785290
# 3   -1.017692 -0.374182
# 4   -1.781797  0.183751
# ..        ...       ...
# 395  0.797057 -0.844019
# 396  1.274623 -1.372587
# 397  1.179110 -1.460681
# 398 -0.158074 -1.078938
# 399  1.083596 -0.990844
#
# [400 rows x 2 columns] 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
print(X.shape)
print(Y.shape)
# Out:
# (400, 2)
# (400,)

# %%
from sklearn.model_selection import train_test_split as tts

# %%
X_train,X_test,ytrain,ytest=tts(X,Y,test_size=0.25,random_state=50)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (300, 2)
# (100, 2)

# %% [markdown]
# ## Model Building and Evaluation

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn import metrics

# %%
accuracy=[]
for i in range(1,101):
    knc=KNeighborsClassifier(n_neighbors=i)
    knc.fit(X_train,ytrain)
    pred=knc.predict(X_test)
    accuracy.append(metrics.accuracy_score(ytest,pred))
print(accuracy)
# Out:
# [0.88, 0.85, 0.93, 0.92, 0.94, 0.93, 0.95, 0.95, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.93, 0.94, 0.94, 0.94, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.93, 0.93, 0.92, 0.93, 0.92, 0.93, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.91, 0.92, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.9, 0.9, 0.88, 0.89, 0.88, 0.88, 0.87, 0.88, 0.87, 0.87, 0.87, 0.87, 0.87, 0.87, 0.86, 0.86, 0.86, 0.86, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.84, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83, 0.83]

# %% [markdown]
# ## Selecting "k" value for KNN

# %%
plt.plot(accuracy)
custom_xticks = list(i for i in range(0,101,5))
plt.xticks(custom_xticks)
plt.figure(figsize=(100, 10)) 
plt.show()

# %%
new_knc=KNeighborsClassifier(n_neighbors=8)
new_knc.fit(X_train,ytrain)
new_pred=new_knc.predict(X_test)

# %%
metrics.confusion_matrix(ytest,new_pred)
# Out:
# array([[69,  1],
#        [ 4, 26]], dtype=int64)

# %%
acc=metrics.accuracy_score(ytest,new_pred)
acc
# Out:
# 0.95

# %%
print('Therefore, the accuracy of this KNN Classifier is: ',acc*100,"%")
# Out:
# Therefore, the accuracy of this KNN Classifier is:  95.0 %

# %% [markdown]
# ### Accuracy of this KNN Classifier model is: 95.0 %
